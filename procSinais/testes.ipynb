# %%
import numpy as np

# %%
teste = np.load('dados.npz',allow_pickle=True)
print(teste['dados'])
# Out:
# [{'modelo': array([[ 450.,  450.,  450., ...,  450.,  450.,  450.],
#         [ 450.,  450.,  450., ...,  450.,  450.,  450.],
#         [ 450.,  450.,  450., ...,  450.,  450.,  450.],
#         ...,
#         [2345., 2345., 2345., ..., 2345., 2345., 2345.],
#         [2345., 2345., 2345., ..., 2345., 2345., 2345.],
#         [2345., 2345., 2345., ..., 2345., 2345., 2345.]]), 'pulso': array([ 3.59552509e-05,  3.50510950e-05,  3.90398949e-05,  4.84468002e-05,
#          4.54049874e-05,  5.17768499e-05,  5.98460048e-05,  6.25486385e-05,
#          6.89875861e-05,  7.27865467e-05,  8.92788216e-05,  8.83107378e-05,
#          9.63363385e-05,  1.14529762e-04,  1.27453995e-04,  1.19368408e-04,
#          1.33723184e-04,  1.60557808e-04,  1.59092589e-04,  1.70907757e-04,
#          1.87888925e-04,  2.01776650e-04,  2.44297763e-04,  2.64491080e-04,
#          2.73686489e-04,  2.80072486e-04,  3.33813241e-04,  3.52226823e-04,
# ...
